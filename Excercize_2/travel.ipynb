# %%
import pandas as pd
df = pd.read_csv("/Users/arnavangarkar/Desktop/Arnav/IIIT/DSP/Excercize_2/airtravel.csv")

# %%
# Display the shape and basic statistics.
df.shape, df.describe()
# Out:
# ((12, 4),
#             "1958"      "1959"      "1960"
#  count   12.000000   12.000000   12.000000
#  mean   381.000000  428.333333  476.166667
#  std     64.530472   69.830097   77.737125
#  min    310.000000  342.000000  390.000000
#  25%    339.250000  387.500000  418.500000
#  50%    360.500000  406.500000  461.000000
#  75%    411.750000  465.250000  514.750000
#  max    505.000000  559.000000  622.000000)

# %%
#  Plot the air travel in July across different years.
import matplotlib.pyplot as plt

plt.plot(df.columns[1:], df.loc[0, df.columns[1:]], marker='o')
plt.title('Air Travel in July (1958-1960)')
plt.xlabel('Year')
plt.ylabel('Number of Passengers')
plt.grid()
plt.show()
